# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

load_dotenv()

prompt = ChatPromptTemplate.from_template(
    "Your are a funny teacher who teaches everything in a funny way and the questions are {question}"
)

formatted_prompt = prompt.invoke({"question":"What is langchain"})

model = ChatGroq(
    model="llama-3.3-70b-versatile"
)
response = model.invoke(formatted_prompt)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from dotenv import load_dotenv
#       2 from langchain_groq import ChatGroq
# ----> 3 from lanchain_core.prompts import ChatPromptTemplate
#       4
#       5 load_dotenv()
#       6
#
# ModuleNotFoundError: No module named 'lanchain_core'
